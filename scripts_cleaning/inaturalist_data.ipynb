# %%
import pandas as pd
import numpy as np

inaturalist_data = pd.read_csv('/content/drive/MyDrive/programming/observations-259859.csv')
inaturalist_data.info()
inaturalist_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51398 entries, 0 to 51397
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51398 non-null  int64
#  1   observed_on        51217 non-null  object
#  2   time_observed_at   48368 non-null  object
#  3   user_id            51398 non-null  int64
#  4   place_guess        51371 non-null  object
#  5   latitude           51398 non-null  float64
#  6   longitude          51398 non-null  float64
#  7   species_guess      48320 non-null  object
#  8   scientific_name    51398 non-null  object
#  9   common_name        50949 non-null  object
#  10  iconic_taxon_name  51398 non-null  object
#  11  taxon_id           51398 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.7+ MB
#               id observed_on         time_observed_at  user_id  \
# 0           1697  2009-02-21                      NaN      170
# ...

# %%
inaturalist_data.info()
#trimming down inaturalist_data to required columns
inaturalist_data = inaturalist_data[['id','observed_on','place_guess','latitude','longitude','scientific_name','common_name','iconic_taxon_name','taxon_id']]
print('_'*50)
#Converting date column to the datetime format.
print('data with only required columns:\n\n')
inaturalist_data['observed_on'] = pd.to_datetime(inaturalist_data['observed_on'])
# #Converting columns to string format
# inaturalist_data[['place_guess','scientific_name','common_name','iconic_taxon_name']].dtype = 'string'
inaturalist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51398 entries, 0 to 51397
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51398 non-null  int64
#  1   observed_on        51217 non-null  object
#  2   time_observed_at   48368 non-null  object
#  3   user_id            51398 non-null  int64
#  4   place_guess        51371 non-null  object
#  5   latitude           51398 non-null  float64
#  6   longitude          51398 non-null  float64
#  7   species_guess      48320 non-null  object
#  8   scientific_name    51398 non-null  object
#  9   common_name        50949 non-null  object
#  10  iconic_taxon_name  51398 non-null  object
#  11  taxon_id           51398 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.7+ MB
# __________________________________________________
# data with only required columns:
#
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# # **filtering out rows with nan in both common_name and scientific_name**

# %%
#filtering out rows with nan in both common_name and scientific_name
print('data without plants with either common name or scientific name:\n\n')
common_or_scintific_name_data = inaturalist_data[(inaturalist_data['common_name'].notna()) | (inaturalist_data['scientific_name'].notna())]
common_or_scintific_name_data.info()
common_or_scintific_name_data
# Out:
# data without plants with either common name or scientific name:
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51398 entries, 0 to 51397
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51398 non-null  int64
#  1   observed_on        51217 non-null  datetime64[ns]
#  2   place_guess        51371 non-null  object
#  3   latitude           51398 non-null  float64
#  4   longitude          51398 non-null  float64
#  5   scientific_name    51398 non-null  object
#  6   common_name        50949 non-null  object
#  7   iconic_taxon_name  51398 non-null  object
#  8   taxon_id           51398 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.9+ MB
#               id observed_on                               place_guess  \
# 0           1697  2009-02-21    200 Pinelake Drive, Elizabeth City, NC
# ...

# %% [markdown]
# # **Filtering out plants**

# %%
#filtering out plants
print('data without plants:\n\n')
no_plantea_data = inaturalist_data[inaturalist_data['iconic_taxon_name'] != 'Plantae']
no_plantea_data.info()
no_plantea_data['iconic_taxon_name'].unique()
# Out:
# data without plants:
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51398 entries, 0 to 51397
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51398 non-null  int64
#  1   observed_on        51217 non-null  datetime64[ns]
#  2   place_guess        51371 non-null  object
#  3   latitude           51398 non-null  float64
#  4   longitude          51398 non-null  float64
#  5   scientific_name    51398 non-null  object
#  6   common_name        50949 non-null  object
#  7   iconic_taxon_name  51398 non-null  object
#  8   taxon_id           51398 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.9+ MB
# array(['Aves', 'Mammalia', 'Reptilia', 'Animalia', 'Amphibia'],
#       dtype=object)

# %%
#data without plants with either common name or scientific name
print('data without plants with either common name or scientific name:\n\n')
no_plantae_common_or_scientific_data = no_plantea_data[(no_plantea_data['common_name'].notna()) | (no_plantea_data['scientific_name'].notna())]
no_plantae_common_or_scientific_data.info()
no_plantae_common_or_scientific_data
# Out:
# data without plants with either common name or scientific name:
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51398 entries, 0 to 51397
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51398 non-null  int64
#  1   observed_on        51217 non-null  datetime64[ns]
#  2   place_guess        51371 non-null  object
#  3   latitude           51398 non-null  float64
#  4   longitude          51398 non-null  float64
#  5   scientific_name    51398 non-null  object
#  6   common_name        50949 non-null  object
#  7   iconic_taxon_name  51398 non-null  object
#  8   taxon_id           51398 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.9+ MB
#               id observed_on                               place_guess  \
# 0           1697  2009-02-21    200 Pinelake Drive, Elizabeth City, NC
# ...

# %% [markdown]
# # **data without plants without any nan values**

# %%
#data without plants without any nan values
print('data without plants without any nan values:\n\n')
no_plantea_data.dropna(inplace = True)
no_plantea_data.info()
no_plantea_data
# Out:
# data without plants without any nan values:
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50746 entries, 0 to 51397
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 50746 non-null  int64
#  1   observed_on        50746 non-null  datetime64[ns]
#  2   place_guess        50746 non-null  object
#  3   latitude           50746 non-null  float64
#  4   longitude          50746 non-null  float64
#  5   scientific_name    50746 non-null  object
#  6   common_name        50746 non-null  object
#  7   iconic_taxon_name  50746 non-null  object
#  8   taxon_id           50746 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.9+ MB
#               id observed_on                               place_guess  \
# 0           1697  2009-02-21    200 Pinelake Drive, Elizabeth City, NC
# ...

# %% [markdown]
# # **Inaturaist_data with plants without nan**

# %%
#inaturaist_data with plants without nan
print('inaturaist_data with plants without nan:\n\n')
inaturalist_data.dropna(inplace = True)
inaturalist_data.info()
inaturalist_data
# Out:
# inaturaist_data with plants without nan:
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50746 entries, 0 to 51397
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 50746 non-null  int64
#  1   observed_on        50746 non-null  datetime64[ns]
#  2   place_guess        50746 non-null  object
#  3   latitude           50746 non-null  float64
#  4   longitude          50746 non-null  float64
#  5   scientific_name    50746 non-null  object
#  6   common_name        50746 non-null  object
#  7   iconic_taxon_name  50746 non-null  object
#  8   taxon_id           50746 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.9+ MB
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# # **Species in norfolk**

# %%
## species in norfolk
areas = {'norfolk' : 96.4}
norfolk_data = inaturalist_data[inaturalist_data['place_guess'].str.contains('Norfolk')]
norfolk_data['count'] = norfolk_data.groupby(['scientific_name'])['scientific_name'].transform('count')
norfolk_data['density'] = norfolk_data['count'] / areas['norfolk'] # count / mi**2
norfolk_data.info()
norfolk_data[inaturalist_data['common_name'].str.contains('Bald Eagle')]
# norfolk_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2548 entries, 7 to 51347
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2548 non-null   int64
#  1   observed_on        2548 non-null   datetime64[ns]
#  2   place_guess        2548 non-null   object
#  3   latitude           2548 non-null   float64
#  4   longitude          2548 non-null   float64
#  5   scientific_name    2548 non-null   object
#  6   common_name        2548 non-null   object
#  7   iconic_taxon_name  2548 non-null   object
#  8   taxon_id           2548 non-null   int64
#  9   count              2548 non-null   int64
#  10  density            2548 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(4)
# memory usage: 238.9+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
areas = {'norfolk' : 96.4, 'newportnews' : 119.6}
newportnews_data = inaturalist_data[inaturalist_data['place_guess'].str.contains('Newport')]
newportnews_data['count'] = newportnews_data.groupby(['scientific_name'])['scientific_name'].transform('count')
newportnews_data['density'] = newportnews_data['count'] / areas['newportnews'] # count / mi**2
# newportnews_data.info()
print(newportnews_data[newportnews_data['common_name'] =='American Beaver'])
norfolk_data[norfolk_data['common_name'] == 'American Beaver']
# inaturalist_data[inaturalist_data['place_guess'].str.contains('Isle of Wight')]
# Out:
#               id observed_on  \
# 3850     6303663  2017-05-21
# 7132    13440846  2016-04-02
# 7410    14304841  2018-07-12
# 17916   40791018  2020-03-26
# 37289   96391843  2021-09-27
# 38862  101538063  2021-11-20
# 41926  108681659  2022-03-15
#
#                                             place_guess   latitude  longitude  \
# 3850                         Greenwood Newport News, VA  37.178440 -76.547596
# 7132          North Newport News, Newport News, VA, USA  37.181273 -76.543913
# 7410              453 Richneck Rd, Newport News, VA, US  37.163614 -76.525269
# 17916  Newport News Park Headquarters, Yorktown, VA, US  37.188122 -76.526153
# 37289                              Newport News, VA, US  37.136887 -76.534039
# 38862  The Virginia Living Museum, Newport News, VA, US  37.069949 -76.479068
# 41926                  Greenwood, Newport News, VA, USA  37.181982 -76.542448
#
#          scientific_name      common_name iconic_taxon_name  taxon_id  count  \
# ...

# %% [markdown]
# # **Comparing densities**

# %%
areas = {'Norfolk' : 96.4, 'Newport News' : 119.6, 'Chesapeake': 351,'Franklin' : 8.36, 'Hampton' : 136.3, 'Poquoson' : 78.46, 'Suffolk' : 429, 'Virginia Beach' : 497, 'Williamsburg' : 9.1, 'Gloucester' : 7.182, 'Isle of Wight' : 363, 'Southampton' : 602, 'Surry' : 0.826562, 'Smithfield' : 10.65, 'York' : 215}
# def calculate_density(data, areas = areas):
#   city_data_dictionary = {city : data[data['place_guess'].str.contains(city)][['id','common_name','scientific_name']] for city in areas.keys()}
#   for city in city_data_dictionary.keys():
#    city_data_dictionary[city]['density'] = city_data_dictionary[city].groupby(['scientific_name'])['scientific_name'].transform('count') / areas[city]
#   return city_data_dictionary
#   # print(city_data_dictionary)
#   # city_density_dictionary = {city : city_count / areas[city] for city, city_count in city_count_dictionary}
#   # return city_density_dictionary
# norfolk_densities_data = pd.DataFrame(calculate_density(inaturalist_data)['Norfolk'])
# newportnews_densities_data = pd.DataFrame(calculate_density(inaturalist_data)['Newport News'])
# # newportnews_densities_data[newportnews_densities_data['common_name'] == 'Bald Eagle'].groupby('common_name').count() / areas['Newport News']
# net_data = pd.merge(norfolk_densities_data, newportnews_densities_data, on = ['id','scientific_name', 'common_name'], suffixes = ("_norfolk","_newportnews"), how = 'outer')
# net_data
# calculate_density(inaturalist_data)
def get_density_df(inaturalist_data = inaturalist_data, areas = areas):
  base_data = inaturalist_data[['common_name','scientific_name']]
  for city in areas.keys():
    city_value_count_data = inaturalist_data[inaturalist_data['place_guess'].str.contains(city)][['common_name','scientific_name']]
    city_value_count_data[city.replace(' ','_')+'_count'] = city_value_count_data.groupby(['common_name'])['common_name'].transform('count')
    city_value_count_data[city.replace(' ','_')+'_density'] = city_value_count_data[city.replace(' ','_')+'_count'] / areas[city]
    print(city_value_count_data)
    #####################   issue with merging
    city_data = base_data.merge(city_value_count_data, how = 'left', on = ['common_name']).reindex(columns = ['common_name','scientific_name',city_value_count_data.columns[-1]])
    base_data[city.replace(' ','_')+'_count'] = city_value_count_data[city.replace(' ','_')+'_count'] # to include count along with density
    base_data[city.replace(' ','_')+'_density'] = city_value_count_data[city.replace(' ','_')+'_density']
  return base_data
density_df = get_density_df()
density_df = density_df.loc[:, (density_df != 0).any()] #select columns atleast one non-zero value
density_df.info()
density_df
# density_df.to_csv('/content/drive/MyDrive/programming/species_density_data.csv')
# density_df.drop_duplicates(subset = ['common_name','scientific_name'], inplace = True)
# density_df.to_csv('/content/drive/MyDrive/programming/species_density_data_drop_dups.csv')
# Out:
#                     common_name               scientific_name  Norfolk_count  \
# 7                    Bald Eagle      Haliaeetus leucocephalus             19
# 8                  Canada Goose             Branta canadensis             40
# 9              Ring-billed Gull            Larus delawarensis             38
# 10     Double-crested Cormorant         Phalacrocorax auritus             25
# 11                Mourning Dove              Zenaida macroura             43
# ...                         ...                           ...            ...
# 51259           Red-tailed Hawk             Buteo jamaicensis             10
# 51318              Domestic Cat                   Felis catus             13
# 51323             Carolina Wren      Thryothorus ludovicianus             34
# 51345       Northern Star Coral            Astrangia poculata              1
# 51347      Eastern Garter Snake  Thamnophis sirtalis sirtalis              9
#
#        Norfolk_density
# ...

# %%
density_df = get_density_df()
density_df = density_df.loc[:, (density_df != 0).any()] #select columns atleast one non-zero value
density_df.info()
density_df
# Out:
#                 common_name         scientific_name
# 0          Great Blue Heron          Ardea herodias
# 1             Black Vulture        Coragyps atratus
# 2            Turkey Vulture          Cathartes aura
# 3           American Beaver       Castor canadensis
# 4              Canada Goose       Branta canadensis
# ...                     ...                     ...
# 51392             Groundhog           Marmota monax
# 51394    Broad-headed Skink     Plestiodon laticeps
# 51395    Eastern Copperhead  Agkistrodon contortrix
# 51396      Great Blue Heron          Ardea herodias
# 51397  Diamondback Terrapin     Malaclemys terrapin
#
# [50746 rows x 2 columns]
#                 common_name         scientific_name
# 0          Great Blue Heron          Ardea herodias
# 1             Black Vulture        Coragyps atratus
# 2            Turkey Vulture          Cathartes aura
# 3           American Beaver       Castor canadensis
# ...
